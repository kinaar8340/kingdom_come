# %% [markdown]
# # Hopf Fibration Fundamentals
#
# Kingdom Come — Module 01: fibers, stereographic projection, and the S² base map.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / "src"))

from kingdom.core.hopf import sample_fiber, hopf_map
from kingdom.viz.hopf_plotly import build_hopf_fibration_figure

fig = build_hopf_fibration_figure(n_fibers=6, eta=0.6, xi1=1.2)
fig.show()

# %% [markdown]
# ## Single fiber inspection

# %%
fiber = sample_fiber(eta=0.5, xi1=1.0, n_points=5)
for i in range(5):
    print(f"ξ₂={fiber['xi2'][i]:.2f}  S³=({fiber['x1'][i]:.3f}, {fiber['x2'][i]:.3f}, {fiber['x3'][i]:.3f}, {fiber['x4'][i]:.3f})")
    print(f"       S²=({fiber['y1'][i]:.3f}, {fiber['y2'][i]:.3f}, {fiber['y3'][i]:.3f})")
